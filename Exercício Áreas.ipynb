# %%
import pandas as pd

# %%
areas = pd.read_csv("C:/Users/20221enpro0294/Downloads/areas.csv", sep = ";", decimal = "," )
areas['Área útil'] = areas["Sala"] + areas["Cozinha"] + areas["Banheiro"] + areas["Dorm"]
areas
# Out:
#       Id Bloco  Andar  Final  Sala  Cozinha  Banheiro  Dorm Rachadura  \
# 0      1     A      1      1  27.8      7.9       5.0  11.6   ausente
# 1      2     A      1      2  28.3      7.3       5.4  13.1   ausente
# 2      3     A      1      3  27.1      7.1       5.0  14.9   ausente
# 3      4     A      1      4  26.5      8.4       3.9  12.4  presente
# 4      5     A      2      1  27.7      7.6       4.7  12.1   ausente
# ..   ...   ...    ...    ...   ...      ...       ...   ...       ...
# 147  148     B     18      4  23.5      7.4       4.3  12.2   ausente
# 148  149     B     19      1  24.1      8.3       4.8  12.9   ausente
# 149  150     B     19      2  24.1      8.0       4.5  10.9   ausente
# 150  151     B     19      3  23.0      8.5       4.3  11.7   ausente
# 151  152     B     19      4  22.7      7.8       4.2  15.7   ausente
#
#       Infiltr  Área útil
# 0     ausente       52.3
# 1     ausente       54.1
# 2     ausente       54.1
# ...

# %%
#Quantidade de empreendimentos

len(areas)
# Out:
# 152

# %%
tabela_bloco = areas["Bloco"].value_counts()
tabela_bloco
# Out:
# Bloco
# A    76
# B    76
# Name: count, dtype: int64

# %%
tabela_andar = areas["Andar"].value_counts()
tabela_andar
# Out:
# Andar
# 1     8
# 11    8
# 18    8
# 17    8
# 16    8
# 15    8
# 14    8
# 13    8
# 12    8
# 10    8
# 2     8
# 9     8
# 8     8
# 7     8
# 6     8
# 5     8
# 4     8
# 3     8
# 19    8
# Name: count, dtype: int64

# %%
df = pd.DataFrame(areas)

df["Área útil"] = df["Sala"] + df["Cozinha"] + df["Banheiro"] + df["Dorm"]

df
# Out:
#       Id Bloco  Andar  Final  Sala  Cozinha  Banheiro  Dorm Rachadura  \
# 0      1     A      1      1  27.8      7.9       5.0  11.6   ausente
# 1      2     A      1      2  28.3      7.3       5.4  13.1   ausente
# 2      3     A      1      3  27.1      7.1       5.0  14.9   ausente
# 3      4     A      1      4  26.5      8.4       3.9  12.4  presente
# 4      5     A      2      1  27.7      7.6       4.7  12.1   ausente
# ..   ...   ...    ...    ...   ...      ...       ...   ...       ...
# 147  148     B     18      4  23.5      7.4       4.3  12.2   ausente
# 148  149     B     19      1  24.1      8.3       4.8  12.9   ausente
# 149  150     B     19      2  24.1      8.0       4.5  10.9   ausente
# 150  151     B     19      3  23.0      8.5       4.3  11.7   ausente
# 151  152     B     19      4  22.7      7.8       4.2  15.7   ausente
#
#       Infiltr  Área útil
# 0     ausente       52.3
# 1     ausente       54.1
# 2     ausente       54.1
# ...

# %%
import matplotlib.pyplot as pit

pit.hist(areas["Sala"], bins = 8)
pit.title("Área")
pit.ylabel("Frequência")
pit.xlabel("Área")
# Out:
# Text(0.5, 0, 'Altura')

# %%
pit.hist(areas["Cozinha"], bins = 8)
pit.title("Área")
pit.ylabel("Frequência")
pit.xlabel("Área")
# Out:
# Text(0.5, 0, 'Área')

# %%
pit.hist(areas["Banheiro"], bins = 8)
pit.title("Área")
pit.ylabel("Frequência")
pit.xlabel("Área")
# Out:
# Text(0.5, 0, 'Área')

# %%
pit.hist(areas["Dorm"], bins = 8)
pit.title("Área")
pit.ylabel("Frequência")
pit.xlabel("Área")
# Out:
# Text(0.5, 0, 'Área')

# %%
pit.hist(areas["Área útil"], bins = 8)
pit.title("Área")
pit.ylabel("Frequência")
pit.xlabel("Área")
# Out:
# Text(0.5, 0, 'Área')

# %%
a
# Out:
# [{'Id': 1,
#   'Bloco': 'A',
#   'Andar': 1,
#   'Final': 1,
#   'Sala': 27.8,
#   'Cozinha': 7.9,
#   'Banheiro': 5.0,
#   'Dorm': 11.6,
#   'Rachadura': 'ausente',
#   'Infiltr': 'ausente',
#   'Área útil': 52.300000000000004},
#  {'Id': 2,
#   'Bloco': 'A',
#   'Andar': 1,
#   'Final': 2,
#   'Sala': 28.3,
#   'Cozinha': 7.3,
#   'Banheiro': 5.4,
#   'Dorm': 13.1,
#   'Rachadura': 'ausente',
#   'Infiltr': 'ausente',
#   'Área útil': 54.1},
#  {'Id': 3,
#   'Bloco': 'A',
#   'Andar': 1,
#   'Final': 3,
#   'Sala': 27.1,
#   'Cozinha': 7.1,
#   'Banheiro': 5.0,
#   'Dorm': 14.9,
#   'Rachadura': 'ausente',
#   'Infiltr': 'ausente',
#   'Área útil': 54.1},
#  {'Id': 4,
#   'Bloco': 'A',
#   'Andar': 1,
#   'Final': 4,
#   'Sala': 26.5,
#   'Cozinha': 8.4,
#   'Banheiro': 3.9,
#   'Dorm': 12.4,
#   'Rachadura': 'presente',
#   'Infiltr': 'presente',
#   'Área útil': 51.199999999999996},
#  {'Id': 5,
#   'Bloco': 'A',
#   'Andar': 2,
#   'Final': 1,
#   'Sala': 27.7,
# ...
