# %%
#Bibliotecas Necessárias

import pandas as pd #CSV
import matplotlib.pyplot as pit # para gráficos
import seaborn as sns # para gráficos
from sklearn.linear_model import LinearRegression # regressão linear
from sklearn.metrics import r2_score # r²

# %%
dados = pd.read_csv("C:/Users/20221enpro0294/Downloads/Salary_Data.csv")
dados
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
pit.scatter(dados['YearsExperience'], dados['Salary'], color = 'lightcoral')
pit.title('Salário anual (dólares) vs. Experiência')
pit.xlabel('Anos de experiência')
pit.ylabel('Salário anual (dólares)')
# Out:
# Text(0, 0.5, 'Salário anual (dólares)')

# %%
x = dados.iloc[:, :1]
y = dados.iloc[:, 1:]
y_pred = modelo.predict(x)

# %%
modelo = LinearRegression()
modelo.fit(x, y)
# Out:
# LinearRegression()

# %%
print('Coeficiente angula (beta_1): ', modelo.coef_)
print('Intercepto (beta_0): ', modelo.intercept_)
# Out:
# Coeficiente angula (beta_1):  [[9449.96232146]]
# Intercepto (beta_0):  [25792.20019867]

# %%
pit.scatter(dados['YearsExperience'], dados['Salary'], color = 'lightcoral')
pit.plot(x, y_pred, color = 'firebrick')
pit.title('Salário anual (dólares) vs. Experiência')
pit.xlabel('Anos de experiência')
pit.ylabel('Salário anual (dólares)')
# Out:
# Text(0, 0.5, 'Salário anual (dólares)')

# %%
r2_score(y, y_pred)
# Out:
# 0.9569566641435086

# %%
import numpy as np

# %%
x_novo = np.array([[4]])
modelo.predict(x_novo)
# Out:
# c:\tools\Anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[63592.04948449]])
