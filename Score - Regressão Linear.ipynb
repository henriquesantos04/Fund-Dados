# %%
#Bibliotecas Necessárias

import pandas as pd #CSV
import matplotlib.pyplot as pit # para gráficos
import seaborn as sns # para gráficos
from sklearn.linear_model import LinearRegression # regressão linear
from sklearn.metrics import r2_score # r²

# %%
dados = pd.read_csv("C:/Users/20221enpro0294/Downloads/score_updated.csv")
dados
# Out:
#     Hours  Scores
# 0     2.5      21
# 1     5.1      47
# 2     3.2      27
# 3     8.5      75
# 4     3.5      30
# ..    ...     ...
# 91    5.8      60
# 92    4.4      44
# 93    6.1      63
# 94    3.7      37
# 95    8.0      84
#
# [96 rows x 2 columns]

# %%
pit.scatter(dados['Hours'], dados['Scores'], color = 'lightcoral')
pit.title('Horas Estudada vs. Nota')
pit.xlabel('Horas')
pit.ylabel('Nota')
# Out:
# Text(0, 0.5, 'Nota')

# %%
x = dados.iloc[:, :1]
y = dados.iloc[:, 1:]
y_pred = modelo.predict(x)

# %%
modelo = LinearRegression()
modelo.fit(x, y)
# Out:
# LinearRegression()

# %%
print('Coeficiente angula (beta_1): ', modelo.coef_)
print('Intercepto (beta_0): ', modelo.intercept_)
# Out:
# Coeficiente angula (beta_1):  [[9.90131826]]
# Intercepto (beta_0):  [1.86357663]

# %%
pit.scatter(dados['Hours'], dados['Scores'], color = 'lightcoral')
pit.plot(x, y_pred, color = 'firebrick')
pit.title('Salário anual (dólares) vs. Experiência')
pit.xlabel('Anos de experiência')
pit.ylabel('Salário anual (dólares)')
# Out:
# Text(0, 0.5, 'Salário anual (dólares)')

# %%
r2_score(y, y_pred)
# Out:
# 0.9813673346564977

# %%
import numpy as np

# %%
x_novo = np.array([[4]])
modelo.predict(x_novo)
# Out:
# c:\tools\Anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[41.46884967]])
